# %%
#area of triangle
base=float( input("base "))
height=float(input("height"))
area=1/2*base*height
print("area of triangle=",area)
# Out:
# base  10
# height 15
# area of triangle= 75.0

# %%
# Out:
# marks of hindi= 55
# marks of english= 55
# marks of maths= 67
# marks of accounts= 65
# marks of business= 87
# total marks= 329.0
# percentage= 6580.0

# %%
#circumference of a circle 

pie=3.14
print("pie=",pie)
radius=float(input("radius"))
circumference_of_circle=2*pie*radius
print("circumferenc=",circumference_of_circle)
# Out:
# pie= 3.14
# radius 20
# circumferenc= 125.60000000000001

# %%
#### cold_drink=int (input("cold drink"))
cold_drink=40
unit=int(input("no. of unit purchased"))
total_bill=cold_drink*unit
print("bill=",total_bill)

discount_amount=total_bill*10/100
print("discount=",discount_amount)
discounted_bill=total_bill-discount_amount
print("discounted bill=",discounted_bill)
# Out:
# no. of unit purchased 7
# bill= 280
# discount= 28.0
# discounted bill= 252.0
